occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_94e45a6834464c70800b9ea2cfee3e82_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_9953281303c541bd96136c3484f6af66_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_e5ffe5dfc17a4c36b7d72fbf9d1e3462_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_6f8c3235370c46d4baf5c207731163aa_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_3707d09f7c444e9cabdb4d4c3112abd8_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_0b1b88f38822461eb5bae575bef1fb3c_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_d084b350b8d44f0585d04d934570c6fa_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_8b18c88927bc4cd591195d2c41bf576e_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_183bca08f0874fd0862c0df1410a5d80_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_362964e65b724afaae0250db5cb85cc3_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_583a015e4d254a68a7a25cb7e0391761_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_f1f425f78f6649bc864b6fb61b788306_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_e6a42f6204ae4e21ba6590eb3926f21f_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_111e1c6deb8a4e1a9aefb8c5dcf17441_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_1db37c1715b6420790a9a27deb5762b4_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_b63a18e434114c6d9413e32c958afddf_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_013b8bd1ed164d96816967a87eaaefd0_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_c67b40d064ef4ba1921509b4cd7ed112_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_d042cf158c8345ffa5820ccc9d8e6487_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_ce6578e830434bbdb2089bd6c3651c70_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_391cba14ad914aa7822dcfbbf3faac93_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_ff7f499bf585404a8eafe1e9858b86e8_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_5fa31b0795814731855351cc238a63da_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_f7605747b85943938b2b395f52c8695a_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_6d961109d4024dbc972fdf21c97159fd_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_8a3ba20d384b44bd9e6240faea2ed8e3_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_90dc1e56edc94cdaad8771ac1d866c0f_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_4d2e71f579fd4b22a5720508efcc2a84_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_298ef0b39fc64bf78193f57b50633b5b_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_c6e13e932c94485aa718c00e85062c44_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_5318d86360ee4bf9aa544924cb279291_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_d32da8981d2041ef9e3a8a1c7b8003fd_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_2ee42a25008a4540be8ee1a4ede9b7db_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_0cdef1f6981241efa48d43bb5ee04c71_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_a29af4398c494645a92d5f2c5f26718b_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_24ef833976e64267b5151dfe407b5b9a_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_144de1b12ec24cff9b20ce510e15a71c_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_ecfaaf8fe7f749e7bd88ad9b28621392_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_b2721bd9fd494fd2ab966d3356759caa_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_d5ed0cb42d20402e8287a6c31138820d_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_bf5ab2e20cfb486eb97b1adb608ad76a_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_b197120f493a47f79e0ef6958dc76215_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_7f19fcdf2f98438082fdfee6f0c405c6_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_bf1f84bc3d53458e9750a9559066a98f_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_e242a70a48024a979df547cfef10c785_occupied.jpg
# /kaggle/input/parking/matchbox_cars_parkinglot/occupied/roi_2b6c35c7ca594f57b0cf6747ae5e3a3f_occupied.jpg

# %% [markdown]
# # **Empty Car Parking Spot Detection System using Keras, CNN, Pytorch**

# %% [markdown]
# ## Introduction
#
# Welcome to this Kaggle notebook on **Empty Parking Spot Detection**. In this project, we aim to develop a system that can automatically detect empty parking spots in an image of a parking area. The notebook is divided into several sections that guide you through the complete process, from setting up the environment to building and deploying the machine learning model.
#
# ### Key Steps Covered:
#
# 1. **Image Annotation**:
#    - We'll start by loading and displaying the parking area image.
#    - A custom tool is provided to manually draw rectangles around parking spots, capturing their coordinates for further processing.
#
# 2. **Data Preparation**:
#    - We'll load and preprocess the images of empty and occupied parking spots.
#    - The dataset is split into training and testing sets, and images are normalized to enhance model performance.
#
# 3. **Model Building**:
#    - A Convolutional Neural Network (CNN) is constructed using Keras to classify parking spots as either empty or occupied.
#    - The model is trained, validated, and eventually saved for reuse.
#
# 4. **Detection and Visualization**:
#    - The trained model is used to analyze the parking area image.
#    - Each parking spot is classified, and the results are visually annotated on the image.
#    - The final image with marked empty and occupied spots is displayed.
#
# By the end of this notebook, you will have a functional system capable of detecting empty parking spots from an image, leveraging deep learning techniques. Let's dive in!

# %% [markdown]
# # **Importing Packages and Extracting Parking Spot Coordinates**

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# Initialize the drawing state
drawing = False
ix, iy = -1, -1

# Load the image
img = cv2.imread("/kaggle/input/parkingarea/parkingarea.png")

# Convert the image from BGR to RGB for displaying with matplotlib
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Create a figure and axis for plotting the image
fig, ax = plt.subplots()
im_plot = ax.imshow(img)

# Function to draw a rectangle on the image
def draw_rectangle(event, x, y, flags, param):
    global ix, iy, drawing

    # When the left mouse button is pressed, start drawing
    if event == cv2.EVENT_LBUTTONDOWN:
        drawing = True
        ix, iy = x, y

    # When the mouse is moved, draw a rectangle if drawing is True
    elif event == cv2.EVENT_MOUSEMOVE:
        if drawing:
            img_rect = img.copy()
            cv2.rectangle(img_rect, (ix, iy), (x, y), (0, 255, 0), 2)
            im_plot.set_data(img_rect)
            plt.draw()

    # When the left mouse button is released, stop drawing
    elif event == cv2.EVENT_LBUTTONUP:
        drawing = False
        cv2.rectangle(img, (ix, iy), (x, y), (0, 255, 0), 2)
        im_plot.set_data(img)
        plt.draw()
        print("Top Left:", (ix, iy))
        print("Bottom Right:", (x, y))

# Function to handle mouse click events
def onclick(event):
    global ix, iy, drawing

    # If the left mouse button is clicked
    if event.button == 1:
        # If not drawing, start drawing
        if not drawing:
            draw_rectangle(cv2.EVENT_LBUTTONDOWN, int(event.xdata), int(event.ydata), None, None)
        # If drawing, stop drawing
        else:
            draw_rectangle(cv2.EVENT_LBUTTONUP, int(event.xdata), int(event.ydata), None, None)

# Function to handle mouse move events
def onmove(event):
    # If drawing and the mouse coordinates are valid, draw a rectangle
    if drawing and event.xdata is not None and event.ydata is not None:
        draw_rectangle(cv2.EVENT_MOUSEMOVE, int(event.xdata), int(event.ydata), None, None)

# Connect the event handlers to the figure canvas
fig.canvas.mpl_connect('button_press_event', onclick)
fig.canvas.mpl_connect('motion_notify_event', onmove)
fig.canvas.mpl_connect('button_release_event', onclick)

# Display the figure
plt.show()

# %% [markdown]
# # **Training Empty Parking Spot Detection Model with Keras and CNN**

# %% [markdown]
# **Purpose of the Code below**
#
# The purpose of this code is to build and train a convolutional neural network (CNN) for detecting empty parking spots from images. The model is trained on grayscale images of parking spots that are either empty or occupied. The trained model is then saved for later use.

# %%
import os
import cv2
import numpy as np

from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.utils import to_categorical

# Paths to dataset
training_data = [
    "/kaggle/input/parking/matchbox_cars_parkinglot/empty",
    "/kaggle/input/parking/matchbox_cars_parkinglot/occupied"
]

# Function to load images
def load_images(training_data):
    images = []
    labels = []
    
    for i, folder in enumerate(training_data):
        for filename in os.listdir(folder):
            try:
                img_path = os.path.join(folder, filename)
                img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
                img = cv2.resize(img, (48, 48))
                
                images.append(img)
                labels.append(i)
                
            except Exception as e:
                print(f"Error loading image {filename}: {e}")
    
    return np.array(images), np.array(labels)

# Load dataset
images, labels = load_images(training_data)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    images, labels, test_size=0.2, random_state=42
)

# Normalize and reshape
X_train = X_train.reshape(-1, 48, 48, 1).astype('float32') / 255
X_test = X_test.reshape(-1, 48, 48, 1).astype('float32') / 255

# One-hot encoding
y_train = to_categorical(y_train, 2)
y_test = to_categorical(y_test, 2)

# Build model
model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(48, 48, 1)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(2, activation='softmax'))

# Compile model
model.compile(
    loss="categorical_crossentropy",
    optimizer="adam",
    metrics=["accuracy"]
)

# Train model
model.fit(
    X_train, y_train,
    batch_size=64,
    epochs=50,
    validation_data=(X_test, y_test)
)

# Save model
model.save("emptyparkingspotdetectionmodel.h5")
# Out:
# Epoch 1/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 8s 182ms/step - accuracy: 0.5254 - loss: 1.1250 - val_accuracy: 0.4798 - val_loss: 1.0564
# Epoch 2/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8079 - loss: 0.4872 - val_accuracy: 0.9566 - val_loss: 0.1518
# Epoch 3/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9329 - loss: 0.1853 - val_accuracy: 0.9422 - val_loss: 0.0998
# Epoch 4/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9505 - loss: 0.1283 - val_accuracy: 0.9480 - val_loss: 0.0950
# Epoch 5/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9540 - loss: 0.1147 - val_accuracy: 0.9595 - val_loss: 0.0741
# Epoch 6/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9533 - loss: 0.1017 - val_accuracy: 0.9451 - val_loss: 0.0923
# Epoch 7/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9556 - loss: 0.0987 - val_accuracy: 0.9769 - val_loss: 0.0543
# Epoch 8/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9577 - loss: 0.0889 - val_accuracy: 0.9769 - val_loss: 0.0828
# Epoch 9/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9587 - loss: 0.0907 - val_accuracy: 0.9798 - val_loss: 0.0613
# Epoch 10/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9646 - loss: 0.0923 - val_accuracy: 0.9277 - val_loss: 0.1489
# Epoch 11/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9664 - loss: 0.0778 - val_accuracy: 0.9769 - val_loss: 0.0513
# Epoch 12/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9739 - loss: 0.0722 - val_accuracy: 0.9798 - val_loss: 0.0653
# Epoch 13/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9707 - loss: 0.0641 - val_accuracy: 0.9827 - val_loss: 0.0513
# Epoch 14/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9758 - loss: 0.0547 - val_accuracy: 0.9827 - val_loss: 0.0503
# Epoch 15/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9653 - loss: 0.1120 - val_accuracy: 0.9306 - val_loss: 0.2213
# Epoch 16/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9575 - loss: 0.1263 - val_accuracy: 0.9480 - val_loss: 0.1178
# Epoch 17/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9638 - loss: 0.0811 - val_accuracy: 0.9855 - val_loss: 0.0545
# Epoch 18/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9723 - loss: 0.0662 - val_accuracy: 0.9798 - val_loss: 0.0487
# Epoch 19/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9722 - loss: 0.0558 - val_accuracy: 0.9855 - val_loss: 0.0408
# Epoch 20/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9781 - loss: 0.0507 - val_accuracy: 0.9913 - val_loss: 0.0373
# Epoch 21/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9879 - loss: 0.0388 - val_accuracy: 0.9827 - val_loss: 0.0460
# Epoch 22/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9768 - loss: 0.0526 - val_accuracy: 0.9884 - val_loss: 0.0380
# Epoch 23/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9897 - loss: 0.0367 - val_accuracy: 0.9682 - val_loss: 0.1002
# Epoch 24/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9750 - loss: 0.0491 - val_accuracy: 0.9740 - val_loss: 0.0521
# Epoch 25/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9321 - loss: 0.1532 - val_accuracy: 0.9653 - val_loss: 0.0743
# Epoch 26/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9209 - loss: 0.2784 - val_accuracy: 0.9711 - val_loss: 0.1240
# Epoch 27/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9712 - loss: 0.0862 - val_accuracy: 0.9740 - val_loss: 0.0675
# Epoch 28/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9698 - loss: 0.0741 - val_accuracy: 0.9682 - val_loss: 0.0805
# Epoch 29/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9657 - loss: 0.0687 - val_accuracy: 0.9769 - val_loss: 0.0803
# Epoch 30/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9757 - loss: 0.0483 - val_accuracy: 0.9798 - val_loss: 0.0480
# Epoch 31/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9799 - loss: 0.0422 - val_accuracy: 0.9827 - val_loss: 0.0469
# Epoch 32/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9654 - loss: 0.0631 - val_accuracy: 0.9884 - val_loss: 0.0531
# Epoch 33/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9846 - loss: 0.0477 - val_accuracy: 0.9798 - val_loss: 0.0421
# Epoch 34/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9814 - loss: 0.0437 - val_accuracy: 0.9855 - val_loss: 0.0370
# Epoch 35/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9763 - loss: 0.0431 - val_accuracy: 0.9798 - val_loss: 0.0554
# Epoch 36/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9829 - loss: 0.0399 - val_accuracy: 0.9884 - val_loss: 0.0454
# Epoch 37/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9850 - loss: 0.0384 - val_accuracy: 0.9884 - val_loss: 0.0415
# Epoch 38/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9867 - loss: 0.0367 - val_accuracy: 0.9855 - val_loss: 0.0451
# Epoch 39/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9923 - loss: 0.0310 - val_accuracy: 0.9827 - val_loss: 0.0363
# Epoch 40/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9851 - loss: 0.0364 - val_accuracy: 0.9451 - val_loss: 0.1210
# Epoch 41/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9687 - loss: 0.0796 - val_accuracy: 0.9798 - val_loss: 0.0492
# Epoch 42/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9668 - loss: 0.0861 - val_accuracy: 0.9538 - val_loss: 0.0906
# Epoch 43/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9695 - loss: 0.0623 - val_accuracy: 0.9827 - val_loss: 0.0421
# Epoch 44/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9825 - loss: 0.0359 - val_accuracy: 0.9740 - val_loss: 0.0552
# Epoch 45/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9681 - loss: 0.0678 - val_accuracy: 0.9827 - val_loss: 0.0543
# Epoch 46/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9785 - loss: 0.0429 - val_accuracy: 0.9827 - val_loss: 0.0370
# Epoch 47/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9734 - loss: 0.0497 - val_accuracy: 0.9884 - val_loss: 0.0405
# Epoch 48/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9891 - loss: 0.0329 - val_accuracy: 0.9827 - val_loss: 0.0384
# Epoch 49/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9834 - loss: 0.0305 - val_accuracy: 0.9913 - val_loss: 0.0421
# Epoch 50/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9839 - loss: 0.0313 - val_accuracy: 0.9913 - val_loss: 0.0299

# %% [markdown]
# # **Building Empty Parking Spot Detecting System with Pytorch & CNN**

# %% [markdown]
# **Purpose of the Code**
#
# The below code is designed to load a pre-trained convolutional neural network (CNN) model for detecting empty parking spots in a given image of a parking area. It processes the image, identifies which spots are empty, and visually marks these spots on the image. The code then displays the annotated image with the count of empty parking spots.

# %%
from keras.models import load_model

# Load the pre-trained model
model = load_model("emptyparkingspotdetectionmodel.h5")
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=['accuracy'])

# List of parking spot coordinates
coordinates = [
    [(20, 8), (58, 88)], [(59, 8), (102, 87)], [(100, 4), (144, 85)], [(145, 8), (184, 87)],
    [(186, 10), (226, 89)], [(225, 9), (268, 90)], [(267, 9), (308, 88)], [(309, 8), (349, 89)],
    [(349, 7), (391, 89)], [(394, 9), (434, 90)], [(436, 10), (474, 91)], [(474, 9), (515, 91)],
    [(517, 12), (573, 94)], [(23, 194), (63, 276)], [(63, 194), (103, 278)], [(103, 197), (142, 277)],
    [(145, 196), (182, 274)], [(187, 197), (227, 278)], [(228, 198), (270, 275)], [(269, 190), (308, 275)],
    [(311, 199), (346, 272)], [(354, 196), (389, 272)], [(396, 196), (433, 273)], [(437, 195), (480, 275)],
    [(487, 201), (511, 273)], [(521, 199), (566, 271)], [(26, 282), (61, 361)], [(65, 284), (103, 359)],
    [(107, 281), (144, 362)], [(152, 287), (175, 365)], [(185, 281), (223, 363)], [(231, 284), (268, 359)],
    [(275, 287), (310, 362)], [(312, 284), (347, 361)], [(353, 284), (389, 363)], [(395, 284), (432, 365)],
    [(437, 285), (470, 364)], [(476, 282), (520, 370)], [(529, 290), (568, 361)]
]

def detect_empty_parking(image, spot):
    x1, y1 = spot[0]
    x2, y2 = spot[1]

    if x1 >= x2 or y1 >= y2 or x1 < 0 or y1 < 0 or x2 > image.shape[1] or y2 > image.shape[0]:
        print("Invalid coordinates for ROI")
        return False

    roi = image[y1:y2, x1:x2]
    if roi.size == 0:
        print("Empty ROI")
        return False

    gray_roi = cv2.cvtColor(roi, cv2.COLOR_BGR2GRAY)
    resized_roi = cv2.resize(gray_roi, (48, 48))
    resized_roi = resized_roi.astype('float32') / 255
    resized_roi = np.expand_dims(resized_roi, axis=0)
    resized_roi = np.expand_dims(resized_roi, axis=-1)

    prediction = model.predict(resized_roi)
    threshold = 0.01
    if prediction[0][0] > threshold:
        return True
    else:
        return False

# Read the input image
current_image = cv2.imread("/kaggle/input/parkingarea/parkingarea.png")

empty_count = 0

# Process each parking spot
for spot in coordinates:
    if detect_empty_parking(current_image, spot):
        cv2.rectangle(current_image, spot[0], spot[1], (0, 255, 0), 2)
        empty_count += 1
    else:
        cv2.rectangle(current_image, spot[0], spot[1], (0, 0, 255), 2)

# Add text overlay
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(current_image, f"Empty Spots: {empty_count}", (50, 50), font, 1.5, (255, 255, 255), 3, cv2.LINE_AA)

# Display the image with matplotlib
plt.figure(figsize=(10, 7))
plt.imshow(cv2.cvtColor(current_image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %% [markdown]
# ## Conclusion
#
# The output image successfully demonstrates the functionality of our empty parking spot detection system. Key observations include:
#
# 1. **Detection Performance**:
#    - The system has identified a total of **31 empty spots**, marked with green rectangles.
#    - Occupied spots are accurately marked with red rectangles, indicating the presence of vehicles.
#
# 2. **Visual Clarity**:
#    - The annotations are clear and well-defined, making it easy to distinguish between empty and occupied spots.
#    - The large, prominent text displaying the count of empty spots (31) provides immediate, useful information.
#
# 3. **System Accuracy**:
#    - The detection appears accurate, with all visible vehicles correctly classified into occupied spots.
#    - Empty spots are also correctly identified, enhancing the utility of the system for real-time applications.
#
# Overall, the system demonstrates a robust capability for detecting and annotating empty parking spots in a given parking area image. This can be highly valuable for applications in smart parking management systems, aiding in efficient use of parking spaces and improving user experience.
#
# Thanks for visiting this project notebook that will add valuable knowledge in your skillset. Please do practice on other parking images!
#
# regards,
#
# **Rizwan**
